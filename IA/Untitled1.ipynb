# %%
##########################################
# ALGORITHM  FOR CLOUD AND BIG DATA      #
# Authors: Carlos Bilbao, Álvaro Ortiz   #
##########################################

import pandas as pd
import numpy as np
import sklearn.metrics
#import significance
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

############################
# 1 PREPARATION		       #
############################

ddbb_wars = pd.read_csv("result.csv", na_values='')

# Feature names
headers_wars = list(ddbb_wars)


############################
# 2 DATA EXPLORATION       #
############################

# Column names
print("Wars Features:")
print(headers_wars,'\n')
print("Columns in Wars = ", len(headers_wars))

# Unique elements of column Country
countries = set(ddbb_wars["country"])
print("Unique elems in column Country for wars = ", countries)


############################
# 3 PREPROCESSING          #
############################

# Feature matrix
X = []

# Label Array
y = []

# We prepare the matrix with the data
for index, row in ddbb_wars.iterrows():

	vector = [#le.transform([row['country']])[0],
              #row['year'],
			  row['inversion'],
			  row['gdp']]
	X.append(vector)
	y.append(row['war'])

X = np.asarray(x)

#X = preprocessing.normalize(X, norm='l2')
# Out:
# Wars Features:
# ['country', 'year', 'allies', 'borderCountries', 'inversion', 'gdp', 'war']
#
# Columns in Wars =  7
# Unique elems in column Country for wars =  {'QAT', 'CHN', 'KHM', 'GHA', 'YPR', 'AZE', 'IRN', 'JAM', 'UGA', 'ITA', 'KEN', 'NOR', 'SGP', 'SAX', 'AUT', 'SLE', 'TUR', 'MEC', 'BRN', 'FIN', 'YUG', 'VNM', 'CUW', 'NPL', 'ZAF', 'PHL', 'OWID_AUH', 'CAN', 'ZWE', 'COD', 'VCT', 'SVN', 'POL', 'CHE', 'ISR', 'HKG', 'ATG', 'GEO', 'SVK', 'CUB', 'AFG', 'NIC', 'ISL', 'IRL', 'TLS', 'GMB', 'EGY', 'IND', 'SUR', 'MEX', 'LBN', 'BHR', 'CYP', 'HTI', 'CMR', 'SAU', 'HAN', 'BEL', 'GBR', 'SIC', 'SYR', 'GUY', 'CRI', 'VEN', 'PRI', 'GDR', 'ROU', 'KAZ', 'URY', 'KGZ', 'UKR', 'PAK', 'PNG', 'BAV', 'MKD', 'EST', 'NDL', 'CAF', 'LUX', 'ECU', 'TUV', 'MHL', 'IDN', 'BEN', 'TCD', 'THA', 'BGD', 'AUS', 'UZB', 'LIE', 'NAM', 'WSM', 'SOM', 'PRY', 'BLZ', 'TZA', 'YAR', 'GFR', 'OWID_CZS', 'LBR', 'DOM', 'PMA', 'AND', 'NLD', 'MAR', 'BFA', 'HSE', 'YEM', 'COL', 'SWE', 'GIB', 'SMR', 'HSG', 'MLT', 'DZA', 'LKA', 'KRO', 'COG', 'MMR', 'MUS', 'DNK', 'TKM', 'PSE', 'NGA', 'MDA', 'SRB', 'LCA', 'GNQ', 'BTN', 'MNG', 'ERI', 'BOL', 'KNA', 'WRT', 'GRD', 'KOR', 'MYS', 'MLI', 'BRB', 'BDI', 'JPN', 'ZMB', 'LTU', 'DJI', 'OMN', 'RWA', 'CIV', 'OWID_GFR', 'LAO', 'COM', 'FRA', 'BHS', 'HRV', 'CHL', 'LSO', 'GTM', 'ARE', 'OWID_KOS', 'LBY', 'RUS', 'USA', 'NER', 'PAN', 'TGO', 'SEN', 'TJK', 'MOD', 'CSK', 'PLW', 'BLR', 'VUT', 'ARM', 'DMA', 'ESP', 'TTO', 'MNE', 'BWA', 'SLB', 'BRA', 'MDV', 'TWN', 'HUN', 'MRT', 'NZL', 'AUH', 'BGR', 'ETH', 'SSD', 'JOR', 'PRT', 'CZK', 'KWT', 'MDG', 'LVA', 'BAD', 'BIH', 'ARG', 'STP', 'GNB', 'SUN', 'FJI', 'KIR', 'GIN', 'IRQ', 'HND', 'MOZ', 'PRK', 'CZE', 'SYC', 'SDN', 'TUN', 'TON', 'TUS', 'CPV', 'OWID_WRL', 'ALB', 'DEU', 'PER', 'MWI', 'GAB', 'SWZ', 'SLV', 'AGO', 'MCO', 'GRC'}

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

clf = LogisticRegression(random_state=0, solver="lbfgs").fit(X_train, y_train)

probs = clf.predict_proba(X_train[:1, :])
score = clf.score(X_train, y_train)
y_pred = clf.predict(X_test)

print(score)
# Out:
# 0.9729991394148021

# %%
for i in range(0, X[:, 0].size):
    color = 'b'
    marker = 'o'
    
    if(y[i] == True): # -> WAR
        color = 'r'
        marker = 'x'
    else:
        plt.plot(X[i, 2], X[i, 1], marker, c = color)
    #plt.plot(X[i, 2], X[i, 1], marker, c = color)
    
plt.xlabel('GDP')
plt.ylabel('Militar Inversion')
fig = plt.gcf()
fig.set_size_inches(40, 40)
plt.show()

# %%
print(np.mean(y))
# Out:
# 0.5282044662449981
